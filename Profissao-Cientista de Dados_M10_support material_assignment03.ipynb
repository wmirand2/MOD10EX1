# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
# Importando bibliotecas
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import pyplot
import plotly.express as px
import seaborn as sns
np.random.seed(2360873)
N = 100

# %%
# Carregando base de dados
df = pd.read_csv('previsao_de_renda.csv')

df1 = df.drop(df[['Unnamed: 0', 'index']], axis=1)
df1.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# ...

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
#grafico de barra para variavel qualitativa sexo no tempo

df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'sexo'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#grafico de barra para variavel qualitativa posse de veículo no tempo

df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'posse_de_veiculo'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#grafico de barra para variavel qualitativa posse de imóvel no tempo
df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'posse_de_imovel'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#grafico de barra para variavel qualitativa tipo de renda no tempo

df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'tipo_renda'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#grafico de barra para variavel qualitativa estado civil no tempo

df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'estado_civil'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#grafico de barra para variavel qualitativa tipo de residencia no tempo

df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'tipo_residencia'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
#grafico de barra para variavel qualitativa educação no tempo

df1.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'educacao'
        , data=df1)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %% [markdown]
# É possivel notar que houve uma mudança na escolaridade das pessoas na base de dados a partir de 09/2015. O número de pessoas com nível secundário de educação caiu bastante enquanto o nível superior aumentou.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
# Perfil médio no tempo usando a variavel sexo

ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\3628243924.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',

# %%
# Perfil medio no tempo usando a variavel posse de veículos

ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_veiculo',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\2147288385.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_veiculo',

# %%
# Perfil medio no tempo usando a variavel posse de imóvel

ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_imovel',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\64665006.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_imovel',

# %%
# Perfil medio no tempo usando a variavel tipo de renda

ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_renda',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\601572602.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_renda',

# %% [markdown]
# Há certa instabilidade nesta variável quando se observa os perfis de médias dos bolsistas e servidores públicos

# %%
# Perfil medio no tempo usando a variavel educação

ax = sns.pointplot(x="data_ref", y="renda", hue = 'educacao',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\606370167.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'educacao',

# %% [markdown]
# Há instabilidade nesta variável quando se observa os perfis de médias de quem tem pós-graduação.

# %%
# Perfil medio no tempo usando a variavel estado civil

ax = sns.pointplot(x="data_ref", y="renda", hue = 'estado_civil',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\3076735302.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'estado_civil',

# %% [markdown]
# Há muita instabilidade nesse perfil de média, por isso podemos descartar esse modelo

# %%
# Perfil medio no tempo usando a variavel tipo de residencia

ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_residencia',
                   data=df1, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df1['data_ref'].unique()

ticks = ax.set_xticks(list(range(df1['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_4932\803918752.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_residencia',

# %% [markdown]
# Há instabiliddae nesse perfil, principalmente no tipo de moradia comunitária
